# %% [markdown]
# # Issue Mining
# Use GitHub API to mine all issues and PRs into a JSON file.

# %%
import requests, json
from util import authHeader

# %%
baseUrl = 'https://api.github.com/'

def apiCall(endpoint, **kwargs):
  return requests.get(baseUrl + endpoint, headers=authHeader, **kwargs)
def issues(page=1):
  return apiCall('repos/lampepfl/dotty/issues?page={0}'.format(page)).json()

# %%
allIssues = []
def processPage(page):
  pageIssues = issues(page)
  if pageIssues:
    print('Obtained {num} issues for page {page}'.format(num=len(pageIssues), page=page))
    allIssues.extend(pageIssues)
    processPage(page+1)
  else:
    print('No issues obtained for page {page}, we are done'.format(page=page))
processPage(1)
# Out:
# Obtained 30 issues for page 1
# Obtained 30 issues for page 2
# Obtained 30 issues for page 3
# Obtained 30 issues for page 4
# Obtained 30 issues for page 5

# %%
with open('issues.json', 'w') as f:
  json.dump(allIssues, f, indent=2)

# %% [markdown]
# # Working with mined issues

# %%
import re, json

# %%
with open('issues.json', 'r') as f:
  data = json.load(f)

# %% [markdown]
# ## Filter standardised issues
# These are the ones which follow pattern:
#
# ```
# ## Minimized code
# ...
# ## Output
# ...
# ```
#
# Minimized code must contain a Scala snippet, and Output must contain an error snippet
#
# **Note**: Can be refactored with `mistune` markdown parser:
#
# ```python
# markdown = mistune.create_markdown(renderer=mistune.AstRenderer())
# markdown(data[3]['body'])
# ```

# %%
def between(target, start, end):
  result = re.search('{start}(.*){end}'.format(start=start, end=end), target, re.DOTALL)
  if result:
    return result.group(1)
  
regions = {
  'minimized_code': ['## Minimized code', '## Output'],
  'output': ['## Output', '## Expectation'],
  'scala_block': ['```[Ss]cala', '```'],
  'code_block': ['```', '```']
}

def region(target, name):
  return between(target, regions[name][0], regions[name][1])

def issue_code(iss):
  body = iss['body']
  min_code = region(body, 'minimized_code')
  if min_code:
    scala_block = region(min_code, 'scala_block')
    return scala_block
filtered = [d for d in data if issue_code(d)]
'Found {0} issues'.format(len(filtered))
# Out:
# 'Found 245 issues'

# %%
with open('filtered.json', 'w') as f:
  json.dump(filtered, f, indent=2)

# %% [markdown]
# # Create a Playground issue from spec

# %%
import os, shutil, textwrap

# %%
playground = '/Users/kmetiuk/Projects/scala3/playground/regression'
shutil.rmtree(playground, ignore_errors=True)
os.makedirs(playground)

# %%
for i in filtered:
  issue_id = i['number']
  print('Processing issue #{0}'.format(issue_id))
  issue_path = os.path.join(playground, 'i{0}.scala'.format(issue_id))

  src = textwrap.dedent(issue_code(i))
  code = textwrap.dedent('''
    // Issue #{issue_num}: https://github.com/lampepfl/dotty/issues/{issue_num}
    {code}
    /*
    Issue text:
    {issue_text}
    */
  '''.format(issue_num=issue_id, issue_text=i['body'], code=src)).lstrip()
  with open(issue_path, 'w') as f:
    f.write(code)
# Out:
# Processing issue #12805
# Processing issue #12803
# Processing issue #12802
# Processing issue #12800
# Processing issue #12796
# Processing issue #12794
# Processing issue #12788
# Processing issue #12776
# Processing issue #12759
# Processing issue #12753
# Processing issue #12739
# Processing issue #12736
# Processing issue #12731
# Processing issue #12729
# Processing issue #12722
# Processing issue #12721
# Processing issue #12715
# Processing issue #12679
# Processing issue #12668
# Processing issue #12663
# Processing issue #12662
# Processing issue #12656
# Processing issue #12655
# Processing issue #12646
# Processing issue #12645
# Processing issue #12643
# Processing issue #12640
# Processing issue #12637
# Processing issue #12627
# Processing issue #12621
# Processing issue #12600
# Processing issue #12577
# Processing issue #12573
# Processing issue #12572
# Processing issue #12571
# Processing issue #12569
# Processing issue #12556
# Processing issue #12537
# Processing issue #12536
# Processing issue #12521
# Processing issue #12514
# Processing issue #12512
# Processing issue #12509
# Processing issue #12508
# Processing issue #12499
# Processing issue #12498
# Processing issue #12493
# Processing issue #12492
# Processing issue #12487
# Processing issue #12478
# Processing issue #12475
# Processing issue #12474
# Processing issue #12465
# Processing issue #12442
# Processing issue #12440
# Processing issue #12415
# Processing issue #12406
# Processing issue #12359
# Processing issue #12346
# Processing issue #12345
# Processing issue #12339
# Processing issue #12328
# Processing issue #12295
# Processing issue #12274
# Processing issue #12252
# Processing issue #12216
# Processing issue #12203
# Processing issue #12199
# Processing issue #12189
# Processing issue #12183
# Processing issue #12179
# Processing issue #12178
# Processing issue #12155
# Processing issue #12126
# Processing issue #12106
# Processing issue #12082
# Processing issue #12077
# Processing issue #12044
# Processing issue #12032
# Processing issue #11998
# Processing issue #11967
# Processing issue #11954
# Processing issue #11919
# Processing issue #11861
# Processing issue #11841
# Processing issue #11834
# Processing issue #11813
# Processing issue #11798
# Processing issue #11764
# Processing issue #11729
# Processing issue #11723
# Processing issue #11712
# Processing issue #11706
# Processing issue #11700
# Processing issue #11697
# Processing issue #11696
# Processing issue #11690
# Processing issue #11681
# Processing issue #11648
# Processing issue #11631
# Processing issue #11572
# Processing issue #11556
# Processing issue #11555
# Processing issue #11547
# Processing issue #11545
# Processing issue #11507
# Processing issue #11499
# Processing issue #11493
# Processing issue #11469
# Processing issue #11449
# Processing issue #11444
# Processing issue #11443
# Processing issue #11412
# Processing issue #11318
# Processing issue #11296
# Processing issue #11294
# Processing issue #11262
# Processing issue #11256
# Processing issue #11253
# Processing issue #11252
# Processing issue #11223
# Processing issue #11221
# Processing issue #11202
# Processing issue #11201
# Processing issue #11174
# Processing issue #11170
# Processing issue #11166
# Processing issue #11163
# Processing issue #11118
# Processing issue #11097
# Processing issue #11054
# Processing issue #11052
# Processing issue #11048
# Processing issue #11043
# Processing issue #11042
# Processing issue #11022
# Processing issue #11004
# Processing issue #10994
# Processing issue #10980
# Processing issue #10961
# Processing issue #10958
# Processing issue #10946
# Processing issue #10944
# Processing issue #10943
# Processing issue #10929
# Processing issue #10906
# Processing issue #10897
# Processing issue #10896
# Processing issue #10889
# Processing issue #10877
# Processing issue #10867
# Processing issue #10864
# Processing issue #10846
# Processing issue #10842
# Processing issue #10841
# Processing issue #10837
# Processing issue #10835
# Processing issue #10834
# Processing issue #10775
# Processing issue #10747
# Processing issue #10726
# Processing issue #10715
# Processing issue #10693
# Processing issue #10671
# Processing issue #10665
# Processing issue #10640
# Processing issue #10615
# Processing issue #10609
# Processing issue #10508
# Processing issue #10497
# Processing issue #10437
# Processing issue #10389
# Processing issue #10370
# Processing issue #10369
# Processing issue #10358
# Processing issue #10349
# Processing issue #10347
# Processing issue #10343
# Processing issue #10318
# Processing issue #10255
# Processing issue #10242
# Processing issue #10231
# Processing issue #10079
# Processing issue #10078
# Processing issue #10077
# Processing issue #10075
# Processing issue #10055
# Processing issue #10047
# Processing issue #10039
# Processing issue #9996
# Processing issue #9959
# Processing issue #9941
# Processing issue #9939
# Processing issue #9891
# Processing issue #9880
# Processing issue #9833
# Processing issue #9825
# Processing issue #9824
# Processing issue #9821
# Processing issue #9795
# Processing issue #9769
# Processing issue #9697
# Processing issue #9695
# Processing issue #9685
# Processing issue #9675
# Processing issue #9668
# Processing issue #9663
# Processing issue #9610
# Processing issue #9511
# Processing issue #9482
# Processing issue #9460
# Processing issue #9446
# Processing issue #9363
# Processing issue #9361
# Processing issue #9360
# Processing issue #9359
# Processing issue #9345
# Processing issue #9334
# Processing issue #9314
# Processing issue #9289
# Processing issue #9287
# Processing issue #9270
# Processing issue #9225
# Processing issue #9110
# Processing issue #9087
# Processing issue #8998
# Processing issue #8991
# Processing issue #8984
# Processing issue #8973
# Processing issue #8967
# Processing issue #8921
# Processing issue #8893
# Processing issue #8887
# Processing issue #8882
# Processing issue #8880
# Processing issue #8835
# Processing issue #8830
# Processing issue #8827
# Processing issue #8823
# Processing issue #8795
# Processing issue #8742
# Processing issue #8740
# Processing issue #8739
# Processing issue #8673
# Processing issue #8646

# %% [markdown]
# # Execute issues

# %%
import subprocess

# %%
scala3_path = '/Users/kmetiuk/Projects/scala3/dotty/bin/scalac'
def scalac(issue_id):
  return subprocess.run('{scalac} i{issue_id}.scala'.format(scalac=scala3_path, issue_id=issue_id),
    cwd=playground, shell=True, capture_output=True)

# %%
compiling_issues = []
for current, issue in enumerate(filtered):
  issue_id = issue['number']
  res = scalac(issue_id)
  print('[{current} / {total}] Issue #{iid} compiled with status {status}'.format(
    iid=issue_id, status=res.returncode, current=current, total=len(filtered)
  ))
  if res.returncode == 0:
    compiling_issues.append(issue_id)
# Out:
# [0 / 245] Issue #12805 compiled with status 0
# [1 / 245] Issue #12803 compiled with status 1
# [2 / 245] Issue #12802 compiled with status 1
# [3 / 245] Issue #12800 compiled with status 1
# [4 / 245] Issue #12796 compiled with status 0
# [5 / 245] Issue #12794 compiled with status 1
# [6 / 245] Issue #12788 compiled with status 1
# [7 / 245] Issue #12776 compiled with status 0
# [8 / 245] Issue #12759 compiled with status 0
# [9 / 245] Issue #12753 compiled with status 1
# [10 / 245] Issue #12739 compiled with status 1
# [11 / 245] Issue #12736 compiled with status 1
# [12 / 245] Issue #12731 compiled with status 1
# [13 / 245] Issue #12729 compiled with status 0
# [14 / 245] Issue #12722 compiled with status 1
# [15 / 245] Issue #12721 compiled with status 1
# [16 / 245] Issue #12715 compiled with status 1
# [17 / 245] Issue #12679 compiled with status 1
# [18 / 245] Issue #12668 compiled with status 0
# [19 / 245] Issue #12663 compiled with status 1
# [20 / 245] Issue #12662 compiled with status 1
# [21 / 245] Issue #12656 compiled with status 1
# [22 / 245] Issue #12655 compiled with status 1
# [23 / 245] Issue #12646 compiled with status 1
# [24 / 245] Issue #12645 compiled with status 1
# [25 / 245] Issue #12643 compiled with status 1
# [26 / 245] Issue #12640 compiled with status 1
# [27 / 245] Issue #12637 compiled with status 1
# [28 / 245] Issue #12627 compiled with status 1
# [29 / 245] Issue #12621 compiled with status 1
# [30 / 245] Issue #12600 compiled with status 1
# [31 / 245] Issue #12577 compiled with status 1
# [32 / 245] Issue #12573 compiled with status 1
# [33 / 245] Issue #12572 compiled with status 1
# [34 / 245] Issue #12571 compiled with status 1
# [35 / 245] Issue #12569 compiled with status 1
# [36 / 245] Issue #12556 compiled with status 1
# [37 / 245] Issue #12537 compiled with status 1
# [38 / 245] Issue #12536 compiled with status 1
# [39 / 245] Issue #12521 compiled with status 1
# [40 / 245] Issue #12514 compiled with status 1
# [41 / 245] Issue #12512 compiled with status 0
# [42 / 245] Issue #12509 compiled with status 1
# [43 / 245] Issue #12508 compiled with status 1
# [44 / 245] Issue #12499 compiled with status 1
# [45 / 245] Issue #12498 compiled with status 1
# [46 / 245] Issue #12493 compiled with status 0
# [47 / 245] Issue #12492 compiled with status 1
# [48 / 245] Issue #12487 compiled with status 1
# [49 / 245] Issue #12478 compiled with status 1
# [50 / 245] Issue #12475 compiled with status 1
# [51 / 245] Issue #12474 compiled with status 0
# [52 / 245] Issue #12465 compiled with status 1
# [53 / 245] Issue #12442 compiled with status 1
# [54 / 245] Issue #12440 compiled with status 1
# [55 / 245] Issue #12415 compiled with status 1
# [56 / 245] Issue #12406 compiled with status 0
# [57 / 245] Issue #12359 compiled with status 1
# [58 / 245] Issue #12346 compiled with status 1
# [59 / 245] Issue #12345 compiled with status 1
# [60 / 245] Issue #12339 compiled with status 1
# [61 / 245] Issue #12328 compiled with status 1
# [62 / 245] Issue #12295 compiled with status 1
# [63 / 245] Issue #12274 compiled with status 1
# [64 / 245] Issue #12252 compiled with status 1
# [65 / 245] Issue #12216 compiled with status 1
# [66 / 245] Issue #12203 compiled with status 1
# [67 / 245] Issue #12199 compiled with status 0
# [68 / 245] Issue #12189 compiled with status 0
# [69 / 245] Issue #12183 compiled with status 1
# [70 / 245] Issue #12179 compiled with status 1
# [71 / 245] Issue #12178 compiled with status 1
# [72 / 245] Issue #12155 compiled with status 0
# [73 / 245] Issue #12126 compiled with status 1
# [74 / 245] Issue #12106 compiled with status 1
# [75 / 245] Issue #12082 compiled with status 1
# [76 / 245] Issue #12077 compiled with status 1
# [77 / 245] Issue #12044 compiled with status 1
# [78 / 245] Issue #12032 compiled with status 1
# [79 / 245] Issue #11998 compiled with status 0
# [80 / 245] Issue #11967 compiled with status 0
# [81 / 245] Issue #11954 compiled with status 1
# [82 / 245] Issue #11919 compiled with status 1
# [83 / 245] Issue #11861 compiled with status 1
# [84 / 245] Issue #11841 compiled with status 1
# [85 / 245] Issue #11834 compiled with status 0
# [86 / 245] Issue #11813 compiled with status 1
# [87 / 245] Issue #11798 compiled with status 1
# [88 / 245] Issue #11764 compiled with status 1
# [89 / 245] Issue #11729 compiled with status 0
# [90 / 245] Issue #11723 compiled with status 0
# [91 / 245] Issue #11712 compiled with status 1
# [92 / 245] Issue #11706 compiled with status 1
# [93 / 245] Issue #11700 compiled with status 1
# [94 / 245] Issue #11697 compiled with status 1
# [95 / 245] Issue #11696 compiled with status 1
# [96 / 245] Issue #11690 compiled with status 1
# [97 / 245] Issue #11681 compiled with status 1
# [98 / 245] Issue #11648 compiled with status 0
# [99 / 245] Issue #11631 compiled with status 1
# [100 / 245] Issue #11572 compiled with status 1
# [101 / 245] Issue #11556 compiled with status 0
# [102 / 245] Issue #11555 compiled with status 1
# [103 / 245] Issue #11547 compiled with status 1
# [104 / 245] Issue #11545 compiled with status 1
# [105 / 245] Issue #11507 compiled with status 1
# [106 / 245] Issue #11499 compiled with status 1
# [107 / 245] Issue #11493 compiled with status 1
# [108 / 245] Issue #11469 compiled with status 1
# [109 / 245] Issue #11449 compiled with status 0
# [110 / 245] Issue #11444 compiled with status 1
# [111 / 245] Issue #11443 compiled with status 1
# [112 / 245] Issue #11412 compiled with status 0
# [113 / 245] Issue #11318 compiled with status 1
# [114 / 245] Issue #11296 compiled with status 0
# [115 / 245] Issue #11294 compiled with status 1
# [116 / 245] Issue #11262 compiled with status 0
# [117 / 245] Issue #11256 compiled with status 1
# [118 / 245] Issue #11253 compiled with status 1
# [119 / 245] Issue #11252 compiled with status 1
# [120 / 245] Issue #11223 compiled with status 1
# [121 / 245] Issue #11221 compiled with status 0
# [122 / 245] Issue #11202 compiled with status 0
# [123 / 245] Issue #11201 compiled with status 1
# [124 / 245] Issue #11174 compiled with status 1
# [125 / 245] Issue #11170 compiled with status 1
# [126 / 245] Issue #11166 compiled with status 1
# [127 / 245] Issue #11163 compiled with status 0
# [128 / 245] Issue #11118 compiled with status 1
# [129 / 245] Issue #11097 compiled with status 1
# [130 / 245] Issue #11054 compiled with status 1
# [131 / 245] Issue #11052 compiled with status 0
# [132 / 245] Issue #11048 compiled with status 0
# [133 / 245] Issue #11043 compiled with status 1
# [134 / 245] Issue #11042 compiled with status 1
# [135 / 245] Issue #11022 compiled with status 0
# [136 / 245] Issue #11004 compiled with status 1
# [137 / 245] Issue #10994 compiled with status 0
# [138 / 245] Issue #10980 compiled with status 1
# [139 / 245] Issue #10961 compiled with status 1
# [140 / 245] Issue #10958 compiled with status 1
# [141 / 245] Issue #10946 compiled with status 1
# [142 / 245] Issue #10944 compiled with status 1
# [143 / 245] Issue #10943 compiled with status 1
# [144 / 245] Issue #10929 compiled with status 1
# [145 / 245] Issue #10906 compiled with status 1
# [146 / 245] Issue #10897 compiled with status 0
# [147 / 245] Issue #10896 compiled with status 1
# [148 / 245] Issue #10889 compiled with status 0
# [149 / 245] Issue #10877 compiled with status 1
# [150 / 245] Issue #10867 compiled with status 1
# [151 / 245] Issue #10864 compiled with status 1
# [152 / 245] Issue #10846 compiled with status 0
# [153 / 245] Issue #10842 compiled with status 0
# [154 / 245] Issue #10841 compiled with status 1
# [155 / 245] Issue #10837 compiled with status 0
# [156 / 245] Issue #10835 compiled with status 0
# [157 / 245] Issue #10834 compiled with status 0
# [158 / 245] Issue #10775 compiled with status 1
# [159 / 245] Issue #10747 compiled with status 0
# [160 / 245] Issue #10726 compiled with status 1
# [161 / 245] Issue #10715 compiled with status 1
# [162 / 245] Issue #10693 compiled with status 0
# [163 / 245] Issue #10671 compiled with status 1
# [164 / 245] Issue #10665 compiled with status 1
# [165 / 245] Issue #10640 compiled with status 1
# [166 / 245] Issue #10615 compiled with status 1
# [167 / 245] Issue #10609 compiled with status 1
# [168 / 245] Issue #10508 compiled with status 1
# [169 / 245] Issue #10497 compiled with status 1
# [170 / 245] Issue #10437 compiled with status 1
# [171 / 245] Issue #10389 compiled with status 0
# [172 / 245] Issue #10370 compiled with status 1
# [173 / 245] Issue #10369 compiled with status 1
# [174 / 245] Issue #10358 compiled with status 1
# [175 / 245] Issue #10349 compiled with status 1
# [176 / 245] Issue #10347 compiled with status 1
# [177 / 245] Issue #10343 compiled with status 1
# [178 / 245] Issue #10318 compiled with status 0
# [179 / 245] Issue #10255 compiled with status 1
# [180 / 245] Issue #10242 compiled with status 1
# [181 / 245] Issue #10231 compiled with status 1
# [182 / 245] Issue #10079 compiled with status 0
# [183 / 245] Issue #10078 compiled with status 1
# [184 / 245] Issue #10077 compiled with status 1
# [185 / 245] Issue #10075 compiled with status 1
# [186 / 245] Issue #10055 compiled with status 1
# [187 / 245] Issue #10047 compiled with status 0
# [188 / 245] Issue #10039 compiled with status 0
# [189 / 245] Issue #9996 compiled with status 1
# [190 / 245] Issue #9959 compiled with status 1
# [191 / 245] Issue #9941 compiled with status 1
# [192 / 245] Issue #9939 compiled with status 1
# [193 / 245] Issue #9891 compiled with status 1
# [194 / 245] Issue #9880 compiled with status 1
# [195 / 245] Issue #9833 compiled with status 0
# [196 / 245] Issue #9825 compiled with status 0
# [197 / 245] Issue #9824 compiled with status 0
# [198 / 245] Issue #9821 compiled with status 1
# [199 / 245] Issue #9795 compiled with status 0
# [200 / 245] Issue #9769 compiled with status 0
# [201 / 245] Issue #9697 compiled with status 1
# [202 / 245] Issue #9695 compiled with status 1
# [203 / 245] Issue #9685 compiled with status 1
# [204 / 245] Issue #9675 compiled with status 1
# [205 / 245] Issue #9668 compiled with status 1
# [206 / 245] Issue #9663 compiled with status 1
# [207 / 245] Issue #9610 compiled with status 1
# [208 / 245] Issue #9511 compiled with status 1
# [209 / 245] Issue #9482 compiled with status 1
# [210 / 245] Issue #9460 compiled with status 1
# [211 / 245] Issue #9446 compiled with status 1
# [212 / 245] Issue #9363 compiled with status 1
# [213 / 245] Issue #9361 compiled with status 1
# [214 / 245] Issue #9360 compiled with status 1
# [215 / 245] Issue #9359 compiled with status 1
# [216 / 245] Issue #9345 compiled with status 1
# [217 / 245] Issue #9334 compiled with status 1
# [218 / 245] Issue #9314 compiled with status 1
# [219 / 245] Issue #9289 compiled with status 1
# [220 / 245] Issue #9287 compiled with status 1
# [221 / 245] Issue #9270 compiled with status 1
# [222 / 245] Issue #9225 compiled with status 1
# [223 / 245] Issue #9110 compiled with status 1
# [224 / 245] Issue #9087 compiled with status 1
# [225 / 245] Issue #8998 compiled with status 1
# [226 / 245] Issue #8991 compiled with status 1
# [227 / 245] Issue #8984 compiled with status 1
# [228 / 245] Issue #8973 compiled with status 1
# [229 / 245] Issue #8967 compiled with status 1
# [230 / 245] Issue #8921 compiled with status 1
# [231 / 245] Issue #8893 compiled with status 1
# [232 / 245] Issue #8887 compiled with status 1
# [233 / 245] Issue #8882 compiled with status 1
# [234 / 245] Issue #8880 compiled with status 0
# [235 / 245] Issue #8835 compiled with status 1
# [236 / 245] Issue #8830 compiled with status 1
# [237 / 245] Issue #8827 compiled with status 1
# [238 / 245] Issue #8823 compiled with status 1
# [239 / 245] Issue #8795 compiled with status 1
# [240 / 245] Issue #8742 compiled with status 0
# [241 / 245] Issue #8740 compiled with status 1
# [242 / 245] Issue #8739 compiled with status 1
# [243 / 245] Issue #8673 compiled with status 1
# [244 / 245] Issue #8646 compiled with status 1

# %% [markdown]
# # Inspect individual issues

# %%
res = scalac(10640)

# %%
def escape_ansi(line):
    ansi_escape = re.compile(r'(?:\x1B[@-_]|[\x80-\x9F])[0-?]*[ -/]*[@-~]')
    return ansi_escape.sub('', line)

print(escape_ansi(res.stderr.decode('utf8')))
# Out:
# -- [E006] Not Found Error: i10640.scala:5:3 ------------------------------------
# 5 |  @targetName("func3_none")
#   |   ^^^^^^^^^^
#   |   Not found: type targetName
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:6:45 -----------------------------------
# 6 |  def func3[A,B](a : A, b : B)(implicit ev1: Not[A<:<Tuple], ev2: Not[B<:<Tuple]): (A,B) = (a,b)
#   |                                             ^^^
#   |                                             Not found: type Not
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:6:66 -----------------------------------
# 6 |  def func3[A,B](a : A, b : B)(implicit ev1: Not[A<:<Tuple], ev2: Not[B<:<Tuple]): (A,B) = (a,b)
#   |                                                                  ^^^
#   |                                                       Not found: type Not
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:7:3 ------------------------------------
# 7 |  @targetName("func3_right")
#   |   ^^^^^^^^^^
#   |   Not found: type targetName
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:8:51 -----------------------------------
# 8 |  def func3[A,B<:Tuple](a : A, b : B)(implicit ev: Not[A<:<Tuple]): *:[A,B] = a *: b
#   |                                                   ^^^
#   |                                                   Not found: type Not
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:9:3 ------------------------------------
# 9 |  @targetName("func3_left")
#   |   ^^^^^^^^^^
#   |   Not found: type targetName
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:10:51 ----------------------------------
# 10 |  def func3[A<:Tuple,B](a : A, b : B)(implicit ev: Not[B<:<Tuple]): Tuple.Concat[A,Tuple1[B]] = a ++ Tuple1(b)
#    |                                                   ^^^
#    |                                                   Not found: type Not
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:11:52 ----------------------------------
# 11 |  def func31[A<:Tuple,B](a : A, b : B)(implicit ev: Not[B<:<Tuple]): Tuple.Concat[A,Tuple1[B]] = a ++ Tuple1(b)
#    |                                                    ^^^
#    |                                                    Not found: type Not
#
# longer explanation available when compiling with `-explain`
# -- [E006] Not Found Error: i10640.scala:12:3 -----------------------------------
# 12 |  @targetName("func3_both")
#    |   ^^^^^^^^^^
#    |   Not found: type targetName
#
# longer explanation available when compiling with `-explain`
# 9 errors found
